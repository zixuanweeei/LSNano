# %%
# %matplotlib inline
import os
import time
import numpy as np
import pandas as pd
import pyabf
import matplotlib.pyplot as plt
from datetime import datetime as dt
from eventsSegments import segment2
from utils import centering, rolling_window
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from tqdm import tnrange, tqdm_notebook

from keras.optimizers import Adagrad
from tslearn.preprocessing import TimeSeriesScalerMinMax, TimeSeriesScalerMeanVariance
from tslearn.shapelets import ShapeletModel, grabocka_params_to_shapelet_size_dict
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_hdf("data/nosub250kHz.h5", key="abf")
dataset.head(5)
# Out:
#      start     stop  width      filename analytes  \
# 0    49275    50541   1246  15o15012.abf      AA3
# 1   378486   379789   1283  15o15012.abf      AA3
# 2  1217885  1219160   1255  15o15012.abf      AA3
# 3  1519286  1520474   1168  15o15012.abf      AA3
# 4  2045561  2046829   1248  15o15012.abf      AA3
#
#                                                  raw  \
# 0  [47.885254, 48.495605, 48.19043, 49.105957, 49...
# 1  [45.443848, 45.443848, 46.0542, 45.13867, 44.5...
# 2  [45.13867, 46.359375, 46.359375, 46.0542, 45.7...
# 3  [46.0542, 46.359375, 45.749023, 45.443848, 46....
# 4  [49.105957, 48.80078, 49.71631, 49.105957, 49....
#
#                                              segment      level
# 0  [3.75836443901062, 1.9273097515106201, 2.23248...  23.104500
# 1  [1.1405439376831055, 0.5301923751831055, -0.08...  22.111444
# 2  [7.2821502685546875, 7.2821502685546875, 4.840...  21.785723
# 3  [4.288922309875488, 3.678570508956909, 3.06821...  21.858732
# 4  [7.265286445617676, 8.180813789367676, 6.04458...  21.747799

# %%
analytes2label = {
    "AA3": 1,
    "GA3": 0,
    "AA3+GA3": -1
}

train_df = dataset.loc[dataset.filename.map(lambda x : x in ("15o15012.abf", "15o18003.abf")), :]
test_df = dataset.loc[dataset.filename.map(lambda x : x in ("15o15023.abf", "15o18017.abf")), :]

train_x = np.array(train_df.segment.tolist()).reshape((-1, 1300, 1))
test_x = np.array(test_df.segment.tolist()).reshape((-1, 1300, 1))

train_label = train_df.analytes.map(lambda x : analytes2label[x])
test_label = test_df.analytes.map(lambda x : analytes2label[x])

print("Number of train samples: ", train_x.shape[0])
print("Number of test samples: ", test_x.shape[0])
print("AA3 count: ", train_label.sum())
print("GA3 count: ", train_label.size - train_label.sum())
# Out:
# Number of train samples:  278
# Number of test samples:  197
# AA3 count:  186
# GA3 count:  92

# %% [raw]
# from imblearn.under_sampling import RandomUnderSampler
# rus = RandomUnderSampler(random_state=42)
# train_x, train_label = rus.fit_resample(train_x.squeeze(), train_label)
# train_x = train_x.reshape((-1, 1300, 1))

# %%
l=0.1
r=4
max_iter = 50
lr = 0.1
weight_regularizer = 0.01
shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=train_x.shape[0],
                                                    ts_sz=train_x.shape[1],
                                                    n_classes=len(set(train_label)),
                                                    l=l,
                                                    r=r)

# Define the model using parameters provided by the authors (except that we use fewer iterations here)
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer=Adagrad(lr=lr),
                        weight_regularizer=weight_regularizer,
                        max_iter=max_iter,
                        verbose_level=2,
                        batch_size=32)
train_x, train_label = shuffle(train_x, train_label)
start_time = time.time()
shp_clf.fit(train_x, train_label)
stop_time = time.time()
# Out:
# Epoch 1/50
#  - 2s - loss: 0.6233 - binary_accuracy: 0.6367 - binary_crossentropy: 0.6035
# Epoch 2/50
#  - 1s - loss: 0.4325 - binary_accuracy: 0.6835 - binary_crossentropy: 0.4124
# Epoch 3/50
#  - 1s - loss: 0.3866 - binary_accuracy: 0.8165 - binary_crossentropy: 0.3652
# Epoch 4/50
#  - 1s - loss: 0.3427 - binary_accuracy: 0.9029 - binary_crossentropy: 0.3196
# Epoch 5/50
#  - 1s - loss: 0.3124 - binary_accuracy: 0.9604 - binary_crossentropy: 0.2873
# Epoch 6/50
#  - 1s - loss: 0.2848 - binary_accuracy: 0.9496 - binary_crossentropy: 0.2576
# Epoch 7/50
#  - 1s - loss: 0.2613 - binary_accuracy: 0.9784 - binary_crossentropy: 0.2320
# Epoch 8/50
#  - 1s - loss: 0.2389 - binary_accuracy: 0.9892 - binary_crossentropy: 0.2076
# Epoch 9/50
#  - 1s - loss: 0.2232 - binary_accuracy: 0.9856 - binary_crossentropy: 0.1900
# Epoch 10/50
#  - 1s - loss: 0.2078 - binary_accuracy: 0.9856 - binary_crossentropy: 0.1728
# Epoch 11/50
#  - 1s - loss: 0.1962 - binary_accuracy: 0.9820 - binary_crossentropy: 0.1597
# Epoch 12/50
#  - 1s - loss: 0.1875 - binary_accuracy: 0.9892 - binary_crossentropy: 0.1495
# Epoch 13/50
#  - 1s - loss: 0.1786 - binary_accuracy: 0.9892 - binary_crossentropy: 0.1392
# Epoch 14/50
#  - 1s - loss: 0.1702 - binary_accuracy: 0.9892 - binary_crossentropy: 0.1296
# Epoch 15/50
#  - 1s - loss: 0.1656 - binary_accuracy: 0.9892 - binary_crossentropy: 0.1239
# Epoch 16/50
#  - 1s - loss: 0.1601 - binary_accuracy: 0.9856 - binary_crossentropy: 0.1174
# Epoch 17/50
#  - 1s - loss: 0.1569 - binary_accuracy: 0.9856 - binary_crossentropy: 0.1132
# Epoch 18/50
#  - 1s - loss: 0.1529 - binary_accuracy: 0.9892 - binary_crossentropy: 0.1083
# Epoch 19/50
#  - 1s - loss: 0.1480 - binary_accuracy: 0.9856 - binary_crossentropy: 0.1026
# Epoch 20/50
#  - 1s - loss: 0.1438 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0977
# Epoch 21/50
#  - 1s - loss: 0.1416 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0949
# Epoch 22/50
#  - 1s - loss: 0.1390 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0917
# Epoch 23/50
#  - 1s - loss: 0.1363 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0884
# Epoch 24/50
#  - 1s - loss: 0.1340 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0858
# Epoch 25/50
#  - 1s - loss: 0.1315 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0828
# Epoch 26/50
#  - 1s - loss: 0.1298 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0806
# Epoch 27/50
#  - 1s - loss: 0.1303 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0808
# Epoch 28/50
#  - 1s - loss: 0.1258 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0760
# Epoch 29/50
#  - 1s - loss: 0.1251 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0750
# Epoch 30/50
#  - 1s - loss: 0.1238 - binary_accuracy: 0.9892 - binary_crossentropy: 0.0734
# Epoch 31/50
#  - 1s - loss: 0.1220 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0714
# Epoch 32/50
#  - 1s - loss: 0.1205 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0697
# Epoch 33/50
#  - 1s - loss: 0.1196 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0686
# Epoch 34/50
#  - 1s - loss: 0.1190 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0679
# Epoch 35/50
#  - 1s - loss: 0.1181 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0668
# Epoch 36/50
#  - 1s - loss: 0.1170 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0656
# Epoch 37/50
#  - 1s - loss: 0.1161 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0646
# Epoch 38/50
#  - 1s - loss: 0.1148 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0632
# Epoch 39/50
#  - 1s - loss: 0.1133 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0616
# Epoch 40/50
#  - 1s - loss: 0.1131 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0613
# Epoch 41/50
#  - 1s - loss: 0.1127 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0608
# Epoch 42/50
#  - 1s - loss: 0.1112 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0592
# Epoch 43/50
#  - 1s - loss: 0.1116 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0596
# Epoch 44/50
#  - 1s - loss: 0.1096 - binary_accuracy: 0.9964 - binary_crossentropy: 0.0575
# Epoch 45/50
#  - 1s - loss: 0.1086 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0565
# Epoch 46/50
#  - 1s - loss: 0.1088 - binary_accuracy: 0.9964 - binary_crossentropy: 0.0567
# Epoch 47/50
#  - 1s - loss: 0.1075 - binary_accuracy: 0.9928 - binary_crossentropy: 0.0555
# Epoch 48/50
#  - 1s - loss: 0.1070 - binary_accuracy: 0.9964 - binary_crossentropy: 0.0549
# Epoch 49/50
#  - 1s - loss: 0.1069 - binary_accuracy: 0.9964 - binary_crossentropy: 0.0548
# Epoch 50/50
#  - 1s - loss: 0.1058 - binary_accuracy: 1.0000 - binary_crossentropy: 0.0538

# %%
predicted_labels = shp_clf.predict(train_x)
train_accuracy = accuracy_score(train_label, predicted_labels)
train_precision = precision_score(train_label, predicted_labels)
train_recall = recall_score(train_label, predicted_labels)
print("Training accuracy:",  train_accuracy)
print("Training precision:", train_precision)
print("Training recall:",    train_recall)
# Out:
# Training accuracy: 0.9964028776978417
# Training precision: 1.0
# Training recall: 0.9946236559139785

# %%
test_plabels = shp_clf.predict(test_x)
test_accuracy = accuracy_score(test_label, test_plabels)
test_precision = precision_score(test_label, test_plabels)
test_recall = recall_score(test_label, test_plabels)
test_f1 = f1_score(test_label, test_plabels)
print("Test accuracy:",  test_accuracy)
print("Test precision:", test_precision)
print("Test recall:",    test_recall)
print("Test F1:",        test_f1)
# Out:
# Test accuracy: 0.883248730964467
# Test precision: 1.0
# Test recall: 0.8516129032258064
# Test F1: 0.9198606271777003
